# %%
from environment.models.weather_control_fixed import WeatherControlledFixedEnv
from matplotlib import pyplot as plt
env = WeatherControlledFixedEnv(fibre_segments=3, interpolate_data=True, interpolation_values=30)

env.max_steps = 50

# %%
while not env.done:
    env.step()

QBERS = env.get_qber()

# %%
plt.figure(figsize=(30, 5))
plt.plot(QBERS)
plt.legend(['QBERz', 'QBERx'])
plt.show()
